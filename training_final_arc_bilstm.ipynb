# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
import tensorflow as tf

# Load processed train-test datasets
X_train = np.load("X_train.npy")
y_train = np.load("y_train.npy")
X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")

# Reshape for LSTM (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build BiLSTM Model
bilstm_model = Sequential([
    Bidirectional(LSTM(64, activation='relu', return_sequences=True), input_shape=(1, X_train.shape[2])),
    Dropout(0.2),
    Bidirectional(LSTM(32, activation='relu', return_sequences=False)),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(4, activation='softmax')  # 4 classes (Minor, Major, Warning, Critical)
])

# Compile BiLSTM Model
bilstm_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train BiLSTM Model
bilstm_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32)

# Evaluate BiLSTM Model
y_pred_bilstm = np.argmax(bilstm_model.predict(X_test), axis=1)
accuracy_bilstm = accuracy_score(y_test, y_pred_bilstm)
print(f"BiLSTM Model Accuracy: {accuracy_bilstm * 100:.2f}%")
print("Classification Report (BiLSTM):\n", classification_report(y_test, y_pred_bilstm))

# Save BiLSTM Model
bilstm_model.save("bilstm_alarm_model.h5")
print("BiLSTM model saved as bilstm_alarm_model.h5")
# Out:
# Epoch 1/50
# 2025-02-27 00:36:37.565526: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/ubuntu/ryh_training/venv/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - accuracy: 0.7884 - loss: 0.5302 - val_accuracy: 0.8687 - val_loss: 0.3560
# Epoch 2/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8890 - loss: 0.3033 - val_accuracy: 0.8964 - val_loss: 0.2908
# Epoch 3/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9010 - loss: 0.2726 - val_accuracy: 0.9083 - val_loss: 0.2521
# Epoch 4/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9065 - loss: 0.2543 - val_accuracy: 0.9136 - val_loss: 0.2559
# Epoch 5/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9122 - loss: 0.2423 - val_accuracy: 0.9090 - val_loss: 0.2491
# Epoch 6/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9159 - loss: 0.2299 - val_accuracy: 0.9165 - val_loss: 0.2374
# Epoch 7/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9193 - loss: 0.2207 - val_accuracy: 0.9253 - val_loss: 0.2118
# Epoch 8/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9204 - loss: 0.2153 - val_accuracy: 0.9031 - val_loss: 0.2345
# Epoch 9/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9250 - loss: 0.2072 - val_accuracy: 0.9241 - val_loss: 0.2069
# Epoch 10/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9258 - loss: 0.2045 - val_accuracy: 0.9214 - val_loss: 0.2171
# Epoch 11/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9267 - loss: 0.1999 - val_accuracy: 0.9179 - val_loss: 0.2289
# Epoch 12/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9287 - loss: 0.1968 - val_accuracy: 0.9155 - val_loss: 0.2140
# Epoch 13/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9286 - loss: 0.1944 - val_accuracy: 0.9212 - val_loss: 0.2111
# Epoch 14/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9304 - loss: 0.1900 - val_accuracy: 0.9208 - val_loss: 0.2176
# Epoch 15/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9308 - loss: 0.1901 - val_accuracy: 0.9311 - val_loss: 0.1894
# Epoch 16/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9314 - loss: 0.1880 - val_accuracy: 0.9138 - val_loss: 0.2232
# Epoch 17/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9328 - loss: 0.1854 - val_accuracy: 0.9233 - val_loss: 0.2145
# Epoch 18/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9331 - loss: 0.1839 - val_accuracy: 0.9263 - val_loss: 0.1966
# Epoch 19/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9336 - loss: 0.1830 - val_accuracy: 0.9331 - val_loss: 0.2014
# Epoch 20/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9336 - loss: 0.1813 - val_accuracy: 0.9360 - val_loss: 0.1863
# Epoch 21/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9356 - loss: 0.1786 - val_accuracy: 0.9339 - val_loss: 0.1968
# Epoch 22/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9347 - loss: 0.1779 - val_accuracy: 0.9335 - val_loss: 0.2003
# Epoch 23/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9360 - loss: 0.1743 - val_accuracy: 0.9258 - val_loss: 0.2010
# Epoch 24/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.9364 - loss: 0.1748 - val_accuracy: 0.9317 - val_loss: 0.1983
# Epoch 25/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9374 - loss: 0.1726 - val_accuracy: 0.9315 - val_loss: 0.1948
# Epoch 26/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9376 - loss: 0.1721 - val_accuracy: 0.9291 - val_loss: 0.1935
# Epoch 27/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9376 - loss: 0.1706 - val_accuracy: 0.9330 - val_loss: 0.1923
# Epoch 28/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9386 - loss: 0.1711 - val_accuracy: 0.9388 - val_loss: 0.1877
# Epoch 29/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9386 - loss: 0.1740 - val_accuracy: 0.9347 - val_loss: 0.1887
# Epoch 30/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9397 - loss: 0.1718 - val_accuracy: 0.9277 - val_loss: 0.1969
# Epoch 31/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9390 - loss: 0.1679 - val_accuracy: 0.9383 - val_loss: 0.1810
# Epoch 32/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9394 - loss: 0.1656 - val_accuracy: 0.9340 - val_loss: 0.1945
# Epoch 33/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9392 - loss: 0.1677 - val_accuracy: 0.9353 - val_loss: 0.1825
# Epoch 34/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9393 - loss: 0.1657 - val_accuracy: 0.9349 - val_loss: 0.1906
# Epoch 35/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9401 - loss: 0.1669 - val_accuracy: 0.9365 - val_loss: 0.1932
# Epoch 36/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9392 - loss: 0.1658 - val_accuracy: 0.9354 - val_loss: 0.1812
# Epoch 37/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9410 - loss: 0.1623 - val_accuracy: 0.9319 - val_loss: 0.1850
# Epoch 38/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9401 - loss: 0.1633 - val_accuracy: 0.9380 - val_loss: 0.1826
# Epoch 39/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9408 - loss: 0.1653 - val_accuracy: 0.9363 - val_loss: 0.1884
# Epoch 40/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9422 - loss: 0.1596 - val_accuracy: 0.9336 - val_loss: 0.1919
# Epoch 41/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9425 - loss: 0.1621 - val_accuracy: 0.9365 - val_loss: 0.1806
# Epoch 42/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9420 - loss: 0.1586 - val_accuracy: 0.9357 - val_loss: 0.1772
# Epoch 43/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9423 - loss: 0.1595 - val_accuracy: 0.9399 - val_loss: 0.1767
# Epoch 44/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9422 - loss: 0.1603 - val_accuracy: 0.9374 - val_loss: 0.1775
# Epoch 45/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9433 - loss: 0.1580 - val_accuracy: 0.9306 - val_loss: 0.1835
# Epoch 46/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9425 - loss: 0.1588 - val_accuracy: 0.9391 - val_loss: 0.1751
# Epoch 47/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9420 - loss: 0.1603 - val_accuracy: 0.9404 - val_loss: 0.1776
# Epoch 48/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9440 - loss: 0.1572 - val_accuracy: 0.9351 - val_loss: 0.1826
# Epoch 49/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9436 - loss: 0.1566 - val_accuracy: 0.9380 - val_loss: 0.1796
# Epoch 50/50
# 4779/4779 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9439 - loss: 0.1541 - val_accuracy: 0.9404 - val_loss: 0.1687
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# BiLSTM Model Accuracy: 94.04%
# Classification Report (BiLSTM):
#                precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94      9558
#            1       0.81      0.93      0.87      1145
#            2       0.77      0.97      0.86      2302
#            3       0.98      0.98      0.98      6557
#
#     accuracy                           0.94     19562
#    macro avg       0.89      0.95      0.91     19562
# weighted avg       0.95      0.94      0.94     19562
#
# BiLSTM model saved as bilstm_alarm_model.h5
